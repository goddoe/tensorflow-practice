# %%
import tensorflow as tf
from tensorflow.examples.tutorials.mnist import input_data
mnist = input_data.read_data_sets("/tmp/data/", one_hot=True)
# Out:
# Extracting /tmp/data/train-images-idx3-ubyte.gz
# Extracting /tmp/data/train-labels-idx1-ubyte.gz
# Extracting /tmp/data/t10k-images-idx3-ubyte.gz
# Extracting /tmp/data/t10k-labels-idx1-ubyte.gz

# %%
learning_rate = 0.001
epochs = 200000
batch_size = 128
display_step = 10

n_input = 784
n_classes = 10

dropout = 0.75

X = tf.placeholder(tf.float32, [None, n_input])
Y = tf.placeholder(tf.float32, [None, n_classes])
keep_prob = tf.placeholder(tf.float32)

# %%
def conv2d(X, W, b, strides=1):
    X = tf.nn.conv2d(X,W,strides=[1,strides, strides,1],padding='SAME')
    X = tf.nn.bias_add(X,b)
    return tf.nn.relu(X)

def maxpool2d(X, k =2):
    # ksize is window!, strides is just strides!
    return tf.nn.max_pool(X,ksize = [1,k,k,1],strides=[1,k,k,1], padding='SAME')

def conv_net(X, weight, biases, dropout):
    X = tf.reshape(X, shape=[-1, 28, 28, 1])
    
    conv1 = conv2d(X, weights['wc1'], biases['bc1'])
    conv1 = maxpool2d(conv1,k=2)
    
    conv2 = conv2d(conv1, weights['wc2'], biases['bc2'])
    conv2 = maxpool2d(conv2, k=2)
    
    fc1 = tf.reshape(conv2, [-1, weights['wd1'].get_shape().as_list()[0]])
    fc1 = tf.add(tf.matmul(fc1, weights['wd1']), biases['bd1'])
    fc1 = tf.nn.relu(fc1)
    
    fc1 = tf.nn.dropout(fc1, dropout)
    
    out = tf.add(tf.matmul(fc1, weights['out']), biases['out'])
    return out

# %%
weights = {
    # 5x5 conv, 1 input, 32 outputs
    # I think '1 input' means the channel's dimension is one
    'wc1': tf.Variable(tf.random_normal([5,5,1,32])),
    'wc2': tf.Variable(tf.random_normal([5,5,32,64])),
    'wd1': tf.Variable(tf.random_normal([7*7*64, 1024])),
    'out': tf.Variable(tf.random_normal([1024, n_classes]))
}

biases = {
    'bc1': tf.Variable(tf.random_normal([32])),
    'bc2': tf.Variable(tf.random_normal([64])),
    'bd1': tf.Variable(tf.random_normal([1024])),
    'out': tf.Variable(tf.random_normal([n_classes]))
}

# %%
pred = conv_net(X,weights, biases, keep_prob)

cost = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(pred,Y))
optimizer = tf.train.AdamOptimizer(learning_rate).minimize(cost)

correct_pred = tf.equal(tf.argmax(pred,1), tf.argmax(Y,1))
accuracy = tf.reduce_mean(tf.cast(correct_pred, tf.float32))

init = tf.initialize_all_variables()

# %%
with tf.Session() as sess:
    sess.run(init)
    step = 1
    
    while step* batch_size < epochs:
        batch_X, batch_Y = mnist.train.next_batch(batch_size)
        
        sess.run(optimizer, feed_dict={X:batch_X, Y:batch_Y, keep_prob:dropout})
        
        if step% display_step == 0:
            loss, acc = sess.run([cost,accuracy], feed_dict={X:batch_X, Y:batch_Y,
                                                               keep_prob: 1.})
            
            print( "Iter " + str(step*batch_size) + ", Minibatch Loss= " + \
                  "{:.6f}".format(loss) + ", Training Accuracy= " + \
                  "{:.5f}".format(acc))
            
        step +=1
        
    print("Optimization Finished!")
    print("Testing Accuracy"+ str(sess.run(accuracy, feed_dict={X: mnist.test.images[:256],
                                                                    Y:mnist.test.labels[:256],
                                                                      keep_prob:1.})))
# Out:
# Iter 1280, Minibatch Loss= 25751.437500, Training Accuracy= 0.28906
# Iter 2560, Minibatch Loss= 11750.339844, Training Accuracy= 0.46094
# Iter 3840, Minibatch Loss= 8031.379883, Training Accuracy= 0.53906
# Iter 5120, Minibatch Loss= 4220.464355, Training Accuracy= 0.75781
# Iter 6400, Minibatch Loss= 3885.512207, Training Accuracy= 0.75781
# Iter 7680, Minibatch Loss= 7055.510742, Training Accuracy= 0.67188
# Iter 8960, Minibatch Loss= 2369.054443, Training Accuracy= 0.86719
# Iter 10240, Minibatch Loss= 2993.466064, Training Accuracy= 0.79688
# Iter 11520, Minibatch Loss= 1518.243042, Training Accuracy= 0.91406
# Iter 12800, Minibatch Loss= 2501.792480, Training Accuracy= 0.79688
# Iter 14080, Minibatch Loss= 1033.386597, Training Accuracy= 0.92188
# Iter 15360, Minibatch Loss= 1650.413574, Training Accuracy= 0.89844
# Iter 16640, Minibatch Loss= 2170.172363, Training Accuracy= 0.87500
# Iter 17920, Minibatch Loss= 802.730957, Training Accuracy= 0.90625
# Iter 19200, Minibatch Loss= 1055.658203, Training Accuracy= 0.88281
# Iter 20480, Minibatch Loss= 325.291321, Training Accuracy= 0.97656
# Iter 21760, Minibatch Loss= 2913.415283, Training Accuracy= 0.83594
# Iter 23040, Minibatch Loss= 1265.977051, Training Accuracy= 0.92188
# Iter 24320, Minibatch Loss= 1383.480225, Training Accuracy= 0.89844
# Iter 25600, Minibatch Loss= 1213.360962, Training Accuracy= 0.87500
# Iter 26880, Minibatch Loss= 959.684265, Training Accuracy= 0.89844
# Iter 28160, Minibatch Loss= 590.082764, Training Accuracy= 0.93750
# Iter 29440, Minibatch Loss= 1030.153931, Training Accuracy= 0.90625
# Iter 30720, Minibatch Loss= 965.631836, Training Accuracy= 0.88281
# Iter 32000, Minibatch Loss= 635.576538, Training Accuracy= 0.94531
# Iter 33280, Minibatch Loss= 674.957275, Training Accuracy= 0.92188
# Iter 34560, Minibatch Loss= 148.506836, Training Accuracy= 0.96094
# Iter 35840, Minibatch Loss= 367.257416, Training Accuracy= 0.96094
# Iter 37120, Minibatch Loss= 1249.489258, Training Accuracy= 0.91406
# Iter 38400, Minibatch Loss= 250.092056, Training Accuracy= 0.97656
# Iter 39680, Minibatch Loss= 208.202423, Training Accuracy= 0.96094
# Iter 40960, Minibatch Loss= 1185.434082, Training Accuracy= 0.90625
# Iter 42240, Minibatch Loss= 353.304993, Training Accuracy= 0.92969
# Iter 43520, Minibatch Loss= 642.861450, Training Accuracy= 0.95312
# Iter 44800, Minibatch Loss= 673.034912, Training Accuracy= 0.93750
# Iter 46080, Minibatch Loss= 160.109619, Training Accuracy= 0.97656
# Iter 47360, Minibatch Loss= 700.751099, Training Accuracy= 0.95312
# Iter 48640, Minibatch Loss= 1366.531860, Training Accuracy= 0.91406
# Iter 49920, Minibatch Loss= 1091.689209, Training Accuracy= 0.92188
# Iter 51200, Minibatch Loss= 368.338684, Training Accuracy= 0.94531
# Iter 52480, Minibatch Loss= 255.555115, Training Accuracy= 0.94531
# Iter 53760, Minibatch Loss= 153.041290, Training Accuracy= 0.98438
# Iter 55040, Minibatch Loss= 494.921509, Training Accuracy= 0.92969
# Iter 56320, Minibatch Loss= 681.821716, Training Accuracy= 0.92188
# Iter 57600, Minibatch Loss= 310.823425, Training Accuracy= 0.96875
# Iter 58880, Minibatch Loss= 344.376282, Training Accuracy= 0.95312
# Iter 60160, Minibatch Loss= 440.264221, Training Accuracy= 0.93750
# Iter 61440, Minibatch Loss= 191.600998, Training Accuracy= 0.96875
# Iter 62720, Minibatch Loss= 411.287109, Training Accuracy= 0.96094
# Iter 64000, Minibatch Loss= 169.317017, Training Accuracy= 0.96875
# Iter 65280, Minibatch Loss= 685.350708, Training Accuracy= 0.92969
# Iter 66560, Minibatch Loss= 246.403931, Training Accuracy= 0.95312
# Iter 67840, Minibatch Loss= 624.764771, Training Accuracy= 0.96875
# Iter 69120, Minibatch Loss= 379.262634, Training Accuracy= 0.96875
# Iter 70400, Minibatch Loss= 305.179382, Training Accuracy= 0.96875
# Iter 71680, Minibatch Loss= 620.900330, Training Accuracy= 0.95312
# Iter 72960, Minibatch Loss= 680.782471, Training Accuracy= 0.97656
# Iter 74240, Minibatch Loss= 528.122925, Training Accuracy= 0.95312
# Iter 75520, Minibatch Loss= 73.050102, Training Accuracy= 0.97656
# Iter 76800, Minibatch Loss= 857.386719, Training Accuracy= 0.92969
# Iter 78080, Minibatch Loss= 126.464569, Training Accuracy= 0.97656
# Iter 79360, Minibatch Loss= 88.969528, Training Accuracy= 0.96875
# Iter 80640, Minibatch Loss= 1.214752, Training Accuracy= 0.99219
# Iter 81920, Minibatch Loss= 419.862823, Training Accuracy= 0.97656
# Iter 83200, Minibatch Loss= 546.483582, Training Accuracy= 0.94531
# Iter 84480, Minibatch Loss= 600.929749, Training Accuracy= 0.93750
# Iter 85760, Minibatch Loss= 470.296021, Training Accuracy= 0.92969
# Iter 87040, Minibatch Loss= 262.122192, Training Accuracy= 0.96875
# Iter 88320, Minibatch Loss= 810.036743, Training Accuracy= 0.94531
# Iter 89600, Minibatch Loss= 529.821106, Training Accuracy= 0.95312
# Iter 90880, Minibatch Loss= 589.834351, Training Accuracy= 0.94531
# Iter 92160, Minibatch Loss= 197.222961, Training Accuracy= 0.96094
# Iter 93440, Minibatch Loss= 419.075073, Training Accuracy= 0.95312
# Iter 94720, Minibatch Loss= 118.018486, Training Accuracy= 0.98438
# Iter 96000, Minibatch Loss= 258.005157, Training Accuracy= 0.95312
# Iter 97280, Minibatch Loss= 201.108948, Training Accuracy= 0.96094
# Iter 98560, Minibatch Loss= 144.517319, Training Accuracy= 0.97656
# Iter 99840, Minibatch Loss= 250.220062, Training Accuracy= 0.96875
# Iter 101120, Minibatch Loss= 323.753876, Training Accuracy= 0.93750
# Iter 102400, Minibatch Loss= 83.712212, Training Accuracy= 0.97656
# Iter 103680, Minibatch Loss= 112.100815, Training Accuracy= 0.97656
# Iter 104960, Minibatch Loss= 372.367279, Training Accuracy= 0.94531
# Iter 106240, Minibatch Loss= 439.891479, Training Accuracy= 0.95312
# Iter 107520, Minibatch Loss= 362.780304, Training Accuracy= 0.96875
# Iter 108800, Minibatch Loss= 561.118774, Training Accuracy= 0.92969
# Iter 110080, Minibatch Loss= 21.036522, Training Accuracy= 0.99219
# Iter 111360, Minibatch Loss= 304.000183, Training Accuracy= 0.95312
# Iter 112640, Minibatch Loss= 79.728584, Training Accuracy= 0.97656
# Iter 113920, Minibatch Loss= 28.292038, Training Accuracy= 0.98438
# Iter 115200, Minibatch Loss= 71.837753, Training Accuracy= 0.97656
# Iter 116480, Minibatch Loss= 456.211243, Training Accuracy= 0.96094
# Iter 117760, Minibatch Loss= 33.671722, Training Accuracy= 0.97656
# Iter 119040, Minibatch Loss= 47.895042, Training Accuracy= 0.96875
# Iter 120320, Minibatch Loss= 414.889252, Training Accuracy= 0.95312
# Iter 121600, Minibatch Loss= 67.761375, Training Accuracy= 0.98438
# Iter 122880, Minibatch Loss= 234.651703, Training Accuracy= 0.95312
# Iter 124160, Minibatch Loss= 86.224030, Training Accuracy= 0.96094
# Iter 125440, Minibatch Loss= 409.902527, Training Accuracy= 0.98438
# Iter 126720, Minibatch Loss= 259.781189, Training Accuracy= 0.97656
# Iter 128000, Minibatch Loss= 239.470566, Training Accuracy= 0.97656
# Iter 129280, Minibatch Loss= 407.130127, Training Accuracy= 0.94531
# Iter 130560, Minibatch Loss= 22.357021, Training Accuracy= 0.98438
# Iter 131840, Minibatch Loss= 618.914062, Training Accuracy= 0.94531
# Iter 133120, Minibatch Loss= 211.901688, Training Accuracy= 0.97656
# Iter 134400, Minibatch Loss= 166.219330, Training Accuracy= 0.96875
# Iter 135680, Minibatch Loss= 220.296051, Training Accuracy= 0.96875
# Iter 136960, Minibatch Loss= 462.977448, Training Accuracy= 0.94531
# Iter 138240, Minibatch Loss= 16.757545, Training Accuracy= 0.99219
# Iter 139520, Minibatch Loss= 227.774902, Training Accuracy= 0.94531
# Iter 140800, Minibatch Loss= 198.620804, Training Accuracy= 0.97656
# Iter 142080, Minibatch Loss= 314.210999, Training Accuracy= 0.96875
# Iter 143360, Minibatch Loss= 279.149750, Training Accuracy= 0.96094
# Iter 144640, Minibatch Loss= 250.974792, Training Accuracy= 0.98438
# Iter 145920, Minibatch Loss= 266.871918, Training Accuracy= 0.96875
# Iter 147200, Minibatch Loss= 209.987518, Training Accuracy= 0.96094
# Iter 148480, Minibatch Loss= 28.032799, Training Accuracy= 0.97656
# Iter 149760, Minibatch Loss= 386.257965, Training Accuracy= 0.94531
# Iter 151040, Minibatch Loss= 288.806580, Training Accuracy= 0.96094
# Iter 152320, Minibatch Loss= 239.211243, Training Accuracy= 0.96094
# Iter 153600, Minibatch Loss= 51.005524, Training Accuracy= 0.98438
# Iter 154880, Minibatch Loss= 33.827293, Training Accuracy= 0.99219
# Iter 156160, Minibatch Loss= 143.659348, Training Accuracy= 0.96875
# Iter 157440, Minibatch Loss= 117.570717, Training Accuracy= 0.98438
# Iter 158720, Minibatch Loss= 183.483978, Training Accuracy= 0.93750
# Iter 160000, Minibatch Loss= 127.521561, Training Accuracy= 0.96875
# Iter 161280, Minibatch Loss= 146.073380, Training Accuracy= 0.97656
# Iter 162560, Minibatch Loss= 361.692078, Training Accuracy= 0.93750
# Iter 163840, Minibatch Loss= 215.268677, Training Accuracy= 0.96094
# Iter 165120, Minibatch Loss= 212.024124, Training Accuracy= 0.97656
# Iter 166400, Minibatch Loss= 83.576477, Training Accuracy= 0.98438
# Iter 167680, Minibatch Loss= 201.331146, Training Accuracy= 0.98438
# Iter 168960, Minibatch Loss= 53.411690, Training Accuracy= 0.98438
# Iter 170240, Minibatch Loss= 67.035957, Training Accuracy= 0.99219
# Iter 171520, Minibatch Loss= 107.707306, Training Accuracy= 0.96875
# Iter 172800, Minibatch Loss= 0.000000, Training Accuracy= 1.00000
# Iter 174080, Minibatch Loss= 22.952787, Training Accuracy= 0.96875
# Iter 175360, Minibatch Loss= 21.489937, Training Accuracy= 0.98438
# Iter 176640, Minibatch Loss= 83.642448, Training Accuracy= 0.97656
# Iter 177920, Minibatch Loss= 91.244019, Training Accuracy= 0.96875
# Iter 179200, Minibatch Loss= 43.711212, Training Accuracy= 0.98438
# Iter 180480, Minibatch Loss= 21.305740, Training Accuracy= 0.99219
# Iter 181760, Minibatch Loss= 111.335526, Training Accuracy= 0.97656
# Iter 183040, Minibatch Loss= 64.231598, Training Accuracy= 0.98438
# Iter 184320, Minibatch Loss= 65.728592, Training Accuracy= 0.98438
# Iter 185600, Minibatch Loss= 63.425232, Training Accuracy= 0.98438
# Iter 186880, Minibatch Loss= 39.353210, Training Accuracy= 0.98438
# Iter 188160, Minibatch Loss= 440.633057, Training Accuracy= 0.95312
# Iter 189440, Minibatch Loss= 169.460815, Training Accuracy= 0.96875
# Iter 190720, Minibatch Loss= 101.581833, Training Accuracy= 0.99219
# Iter 192000, Minibatch Loss= 41.180157, Training Accuracy= 0.96875
# Iter 193280, Minibatch Loss= 128.875549, Training Accuracy= 0.97656
# Iter 194560, Minibatch Loss= 6.519798, Training Accuracy= 0.99219
# Iter 195840, Minibatch Loss= 64.040176, Training Accuracy= 0.99219
# Iter 197120, Minibatch Loss= 145.270279, Training Accuracy= 0.97656
# Iter 198400, Minibatch Loss= 119.779533, Training Accuracy= 0.96875
# Iter 199680, Minibatch Loss= 21.926628, Training Accuracy= 0.99219
# Optimization Finished!
# Testing Accuracy0.988281
